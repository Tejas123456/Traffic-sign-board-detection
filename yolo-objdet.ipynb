# %%
# !git clone https://github.com/opencv/opencv.git
# %cd opencv 
# %cd ..
# !git checkout 3.3.1 
# !cd ..
# !ls
# %cd /
# !rm -r content/opencv/
# !wget https://github.com/opencv/opencv/archive/3.4.0.zip -O opencv-3.4.0.zip
# !wget https://github.com/opencv/opencv_contrib/archive/3.4.0.zip -O opencv_contrib-3.4.0.zip
# !sudo apt-get install unzip
# !unzip opencv-3.4.0.zip
# !unzip opencv_contrib-3.4.0.zip

# %%
# %cd  opencv-3.4.0
# !mkdir build
# %cd build
# Out:
# /opencv-3.4.0
# /opencv-3.4.0/build

# %%
# !cmake -DCMAKE_BUILD_TYPE=Release -DCMAKE_INSTALL_PREFIX=/usr/local -DOPENCV_EXTRA_MODULES_PATH=../../opencv_contrib-3.4.0/modules -DOPENCV_ENABLE_NONFREE=True ..

# %% [markdown]
# # **Start from here....**

# %%
# !pwd
# %cd /
# Out:
# /

# %%
# !git clone https://github.com/pjreddie/darknet.git
# %cd darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 5901, done.
# remote: Total 5901 (delta 0), reused 0 (delta 0), pack-reused 5901
# Receiving objects: 100% (5901/5901), 6.17 MiB | 29.79 MiB/s, done.
# Resolving deltas: 100% (3923/3923), done.
# /darknet

# %%
# %cd /darknet/
# !make
# Out:
# /darknet
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# gcc -Iinclude/ -Isrc/ -DGPU -I/usr/local/cuda/include/ -DCUDNN  -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -DGPU -DCUDNN -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘time_gpu’:
# ./src/gemm.c:232:9: warning: ‘cudaThreadSynchronize’ is deprecated [-Wdeprecated-declarations]
#          cudaThreadSynchronize();
#          ^~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:11,
#                  from ./src/utils.h:5,
#                  from ./src/gemm.c:2:
# /usr/local/cuda/include/cuda_runtime_api.h:947:57: note: declared here
#  extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaThreadSynchronize(void);
#                                                          ^~~~~~~~~~~~~~~~~~~~~
# ...

# %%
# !git clone https://github.com/Tejas123456/annotated_data.git
print("done")
# !pwd
# %cd ..
# Out:
# Cloning into 'annotated_data'...
# remote: Enumerating objects: 1, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 2068 (delta 0), reused 0 (delta 0), pack-reused 2067
# Receiving objects: 100% (2068/2068), 244.69 MiB | 37.16 MiB/s, done.
# Resolving deltas: 100% (52/52), done.
# Checking out files: 100% (2640/2640), done.
# done

# %%
# !mkdir /darknet/data/obj
# !cp ./annotated_data/obj4/* /darknet/data/obj/
# !cp ./annotated_data/obj3/* /darknet/data/obj/
# !cp ./annotated_data/obj/* /darknet/data/obj/

# %%
# %cd /darknet/data/obj/
# !ls | wc -l
# Out:
# /darknet/data/obj
# 2426

# %%
# %cd /
# !git clone https://github.com/KleinYuan/easy-yolo.git
# !sudo mv easy-yolo/darknet19_448.conv.23 /darknet/
# Out:
# /
# Cloning into 'easy-yolo'...
# remote: Enumerating objects: 188, done.
# remote: Total 188 (delta 0), reused 0 (delta 0), pack-reused 188
# Receiving objects: 100% (188/188), 70.36 MiB | 42.86 MiB/s, done.
# Resolving deltas: 100% (60/60), done.

# %%
# %cd darknet/
# !pwd
# !./darknet detector train data/obj.data yolo-obj.cfg darknet19_448.conv.23
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# %cd darknet/
# !pwd
# !ls -l
# !sudo ./darknet detector test cfg/coco.data yolo-obj-v2.cfg darknet19_448.conv.23 data/dog.jpg
# !sudo ./darknet detector train data/obj.data yolo-obj-v2.cfg backup/yolo-obj-v2_900.weights
# Out:
# yolo-obj-v2
# Couldn't open file: yolo-obj-v2.cfg

# %%
# !mkdir /weights
# %cd /weights
# !git init
# !git remote add origin https://github.com/Tejas123456/YOLOv2-weights.git
# !git config --global user.email "bhadreshatejas@gmail.com"
# !git config --global user.name "Tejas123456"
# !git add .
# !git commit -m "colab"
# !git push origin master
# Out:
# fatal: remote origin already exists.
# fatal: could not read Username for 'https://github.com': No such device or address
